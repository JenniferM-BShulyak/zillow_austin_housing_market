# %%
import pandas as pd
import json

# %%
#reading json
geojson_df = pd.read_json('../geojson_data/tx_texas_zip_codes_geo.min.json')

# %%
geojson_df.head(3)
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'STATEFP10'...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'STATEFP10'...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'STATEFP10'...

# %%
# load data using Python JSON module
with open('../geojson_data/tx_texas_zip_codes_geo.min.json','r') as f:
    data = json.loads(f.read())

# %%
# Normalizing data
geo_df = pd.json_normalize(data, record_path = 
                           ['features'], meta =
                           ['original_number_of_clusters','Scaler','family_min_samples_percentage'], meta_prefix='config_params_', record_prefix='dbscan_', errors = 'ignore')

# %%
geo_df.head(3)
# Out:
#   dbscan_type dbscan_properties.STATEFP10 dbscan_properties.ZCTA5CE10  \
# 0     Feature                          48                       75801
# 1     Feature                          48                       75839
# 2     Feature                          48                       78336
#
#   dbscan_properties.GEOID10 dbscan_properties.CLASSFP10  \
# 0                   4875801                          B5
# 1                   4875839                          B5
# 2                   4878336                          B5
#
#   dbscan_properties.MTFCC10 dbscan_properties.FUNCSTAT10  \
# 0                     G6350                            S
# 1                     G6350                            S
# 2                     G6350                            S
#
#    dbscan_properties.ALAND10  dbscan_properties.AWATER10  \
# 0                  555807428                     6484251
# 1                  381863557                     3928555
# ...

# %%
#Getting specific data points for the Austin area
geo_with_index = geo_df.set_index("dbscan_properties.ZCTA5CE10")
geo_with_index.head(3)
# Out:
#                             dbscan_type dbscan_properties.STATEFP10  \
# dbscan_properties.ZCTA5CE10
# 75801                           Feature                          48
# 75839                           Feature                          48
# 78336                           Feature                          48
#
#                             dbscan_properties.GEOID10  \
# dbscan_properties.ZCTA5CE10
# 75801                                         4875801
# 75839                                         4875839
# 78336                                         4878336
#
#                             dbscan_properties.CLASSFP10  \
# dbscan_properties.ZCTA5CE10
# 75801                                                B5
# 75839                                                B5
# 78336                                                B5
#
#                             dbscan_properties.MTFCC10  \
# dbscan_properties.ZCTA5CE10
# 75801                                           G6350
# ...

# %%
zipcodes = ['78744',
            '78735',
            '78741',
            '78733',
            '78746',
            '78701',
            '78702',
            '78721',
            '78722',
            '78723',
            '78754',
            '78731',
            '78732',
            '78726',
            '78750',
            '78757',
            '78752',
            '78724',
            '78753',
            '78758',
            '78727',
            '78759',
            '78745',
            '78729',
            '78748',
            '78717',
            '78751',
            '78705',
            '78704',
            '78703']
austingeo_df = geo_df[geo_df['dbscan_properties.ZCTA5CE10'].isin(zipcodes)]

# %%
austingeo_df.head()
# Out:
#     dbscan_type dbscan_properties.STATEFP10 dbscan_properties.ZCTA5CE10  \
# 479     Feature                          48                       78759
# 480     Feature                          48                       78703
# 481     Feature                          48                       78735
# 483     Feature                          48                       78721
# 731     Feature                          48                       78744
#
#     dbscan_properties.GEOID10 dbscan_properties.CLASSFP10  \
# 479                   4878759                          B5
# 480                   4878703                          B5
# 481                   4878735                          B5
# 483                   4878721                          B5
# 731                   4878744                          B5
#
#     dbscan_properties.MTFCC10 dbscan_properties.FUNCSTAT10  \
# 479                     G6350                            S
# 480                     G6350                            S
# ...

# %%
austin_df = austingeo_df.drop(["config_params_original_number_of_clusters", "config_params_Scaler", 'config_params_family_min_samples_percentage'], axis =1)

# %%
austin_df.head()
# Out:
#     dbscan_type dbscan_properties.STATEFP10 dbscan_properties.ZCTA5CE10  \
# 479     Feature                          48                       78759
# 480     Feature                          48                       78703
# 481     Feature                          48                       78735
# 483     Feature                          48                       78721
# 731     Feature                          48                       78744
#
#     dbscan_properties.GEOID10 dbscan_properties.CLASSFP10  \
# 479                   4878759                          B5
# 480                   4878703                          B5
# 481                   4878735                          B5
# 483                   4878721                          B5
# 731                   4878744                          B5
#
#     dbscan_properties.MTFCC10 dbscan_properties.FUNCSTAT10  \
# 479                     G6350                            S
# 480                     G6350                            S
# ...

# %%
# Renaming Columns for geojson
austin_df.rename(columns= {'dbscan_type':'type',
                        'dbscan_properties.STATEFP10' : 'STATEFP10',
                       'dbscan_properties.ZCTA5CE10' : 'ZCTA5CE10',
                       'dbscan_properties.GEOID10' : 'GEOID10',
                       'dbscan_properties.CLASSFP10' : 'CLASSFP10',
                       'dbscan_properties.MTFCC10' : 'MTFCC10',
                       'dbscan_properties.FUNCSTAT10' : 'FUNCSTAT10',
                       'dbscan_properties.ALAND10' : 'ALAND10',
                       'dbscan_properties.AWATER10': 'AWATER10',
                       'dbscan_properties.INTPTLAT10': 'INTPTLAT10',
                       'dbscan_properties.INTPTLON10': 'INTPTLON10',
                       'dbscan_properties.PARTFLG10': 'PARTFLG10',
                       'dbscan_geometry.type': 'geometry.type',
                       'dbscan_geometry.coordinates':'geometry.coordinates'},
             inplace=True)

# %%
austin_df.dtypes
# Out:
# type                    object
# STATEFP10               object
# ZCTA5CE10               object
# GEOID10                 object
# CLASSFP10               object
# MTFCC10                 object
# FUNCSTAT10              object
# ALAND10                  int64
# AWATER10                 int64
# INTPTLAT10              object
# INTPTLON10              object
# PARTFLG10               object
# geometry.type           object
# geometry.coordinates    object
# dtype: object

# %%
austin_df.to_json('..//geojson_data/austinzipcode_geo.json', orient="records")
austin_df.to_csv("../geojson_data/austinzipcode_geo.csv", index=False)

# %%
rent_df = pd.read_csv('../geojson_data/rentals_over_timeGeo.csv')
zest_df = pd.read_csv('../geojson_data/zest_over_timeGeo.csv')

# %%
rent_df.dtypes
# Out:
# zip_code        int64
# 2015-03-31    float64
# 2015-04-30    float64
# 2015-05-31    float64
# 2015-06-30    float64
#                ...
# 2022-09-30    float64
# 2022-10-31    float64
# 2022-11-30    float64
# 2022-12-31    float64
# 2023-01-31    float64
# Length: 96, dtype: object

# %%
austin_merge = austin_df.rename(columns= {'ZCTA5CE10' : 'zip_code'})
austin_merge = austin_merge.astype({"zip_code": int})

# %%
austin_merge = austin_merge.drop(["type","GEOID10", "CLASSFP10", "MTFCC10", "FUNCSTAT10", "ALAND10", "AWATER10", "STATEFP10", "PARTFLG10", "geometry.type", "geometry.coordinates"], axis=1)

# %%
rent_geo = pd.merge(rent_df, austin_merge, on="zip_code", how="left")
zest_geo = pd.merge(zest_df, austin_merge, on="zip_code", how="left")
rent_geo = rent_geo.rename(columns= {'zip_code' : 'ZCTA5CE10',
                           'INTPTLON10': 'longitude',
                           'INTPTLAT10': 'latitude'})
zest_geo = zest_geo.rename(columns= {'zip_code' : 'ZCTA5CE10',
                           'INTPTLON10': 'longitude',
                           'INTPTLAT10': 'latitude'})

# %%
#dropping na values in lan and long
rent_geo = rent_geo.dropna(subset=['latitude', 'longitude'])
zest_geo = zest_geo.dropna(subset=['latitude', 'longitude'])

# %%
rent_geo.head()
# Out:
#    ZCTA5CE10   2015-03-31   2015-04-30   2015-05-31   2015-06-30   2015-07-31  \
# 1      78748  1128.231561  1136.914112  1146.573022  1149.119332  1149.187263
# 3      78745  1065.842515  1097.610540  1119.407051  1131.108759  1133.466659
# 4      78744          NaN          NaN          NaN          NaN          NaN
# 5      78735          NaN          NaN          NaN          NaN          NaN
# 6      78704  1488.738257  1480.981293  1488.485541  1491.039788  1510.267406
#
#     2015-08-31   2015-09-30   2015-10-31   2015-11-30  ...   2022-06-30  \
# 1  1144.169272  1150.585290  1148.356735  1147.706618  ...  1720.333617
# 3  1140.234407  1126.299002  1121.670385  1122.668728  ...  1739.359795
# 4          NaN          NaN          NaN          NaN  ...  1762.219544
# 5          NaN          NaN          NaN          NaN  ...  1933.488720
# 6  1520.833861  1516.322412  1497.978375  1497.950902  ...  2286.233808
#
# ...

# %%
rent_geo.to_csv('../geojson_data/rent_geo.csv', index=False)
zest_geo.to_csv('../geojson_data/zest_geo.csv', index=False)

rent_geo.to_json('..//geojson_data/geo_jsonmap/rent_geo.json', orient="records")
zest_geo.to_json('..//geojson_data/geo_jsonmap/zest_geo.json', orient="records")

# %%
#summing by year to get average 
rent_geo["2015"] = rent_geo[["2015-03-31", "2015-04-30", "2015-05-31", "2015-06-30", "2015-07-31", "2015-08-31", "2015-09-30", "2015-10-31", "2015-11-30", "2015-12-31"]].mean(axis=1)
rent_geo["2016"] = rent_geo[["2016-01-31", "2016-02-29", "2016-03-31", "2016-04-30", "2016-05-31", "2016-06-30", "2016-07-31", "2016-08-31", "2016-09-30", "2016-10-31", "2016-11-30", "2016-12-31"]].mean(axis=1) 
rent_geo["2017"] = rent_geo[["2017-01-31", "2017-02-28", "2017-03-31", "2017-04-30", "2017-05-31", "2017-06-30", "2017-07-31", "2017-08-31", "2017-09-30", "2017-10-31", "2017-11-30", "2017-12-31"]].mean(axis=1) 
rent_geo["2018"] = rent_geo[["2018-01-31", "2018-02-28", "2018-03-31", "2018-04-30", "2018-05-31", "2018-06-30", "2018-07-31", "2018-08-31", "2018-09-30", "2018-10-31", "2018-11-30", "2018-12-31"]].mean(axis=1) 
rent_geo["2019"] = rent_geo[["2019-01-31", "2019-02-28", "2019-03-31", "2019-04-30", "2019-05-31", "2019-06-30", "2019-07-31", "2019-08-31", "2019-09-30", "2019-10-31", "2019-11-30", "2019-12-31"]].mean(axis=1)
rent_geo["2020"] = rent_geo[["2020-01-31", "2020-02-29", "2020-03-31", "2020-04-30", "2020-05-31", "2020-06-30", "2020-07-31", "2020-08-31", "2020-09-30", "2020-10-31", "2020-11-30", "2020-12-31"]].mean(axis=1) 
rent_geo["2021"] = rent_geo[["2021-01-31", "2021-02-28", "2021-03-31", "2021-04-30", "2021-05-31", "2021-06-30", "2021-07-31", "2021-08-31", "2021-09-30", "2021-10-31", "2021-11-30", "2021-12-31"]].mean(axis=1) 
